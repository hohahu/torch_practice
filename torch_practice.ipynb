# %%
"""
순전파: 입력데이터(input_data)로부터 예측값(predict)을 계산하는 과정
ex) 예측값 = 가중치 * 입력값 + 편향
"""
weight = 0.5 # 가중치
learning_rate = 0.01 # 학습률
gradient = -0.8

# 가중치 업데이트 0.508 = 0.5 - 0.01 * (-0.8)
weight = weight - learning_rate * gradient
print(f'가중치 업데이트: {weight}')
# Out:
# 가중치 업데이트: 0.508
